# %% [markdown]
# $$\min\limits_{x \in \mathbb{R}^{d}} x^{2} + \frac{1}{100}y^{2}$$

# %%
import numpy as np
import numpy.linalg as la
def gradient_method_backtracking(f, g, xO, s, alpha, beta, epsilon):
    x = xO
    grad = g(x)
    fun_val = f(x)
    iter = 0
    while la.norm(grad) > epsilon:
        iter = iter + 1
        t = s
        while fun_val - f(x - t * grad) < alpha * t * la.norm(grad) ** 2 :
            t=beta * t
        x = x - t * grad
        fun_val = f(x)
        grad = g(x)
        print('iter_number = {0:3d}'.format(iter), 'norm_grad = {0:2.6f}'.format(la.norm(grad)),
              'fun_val = {0:2.6f}'.format(fun_val))
    return x, fun_val

# %%
A = np.array([[1, 0], [0, 0.01]])
f = lambda x : x @ A @ x
g = lambda x : 2 * A @ x
x0 = np.array([0.01, 1.0])
x, fun_val = gradient_method_backtracking(f, g, x0, 2, 0.25, 0.5, 1e-5)
# Out:
# iter_number =   1 norm_grad = 0.028003 fun_val = 0.009704
# iter_number =   2 norm_grad = 0.027730 fun_val = 0.009324
# iter_number =   3 norm_grad = 0.027465 fun_val = 0.008958
# iter_number =   4 norm_grad = 0.027209 fun_val = 0.008608
# iter_number =   5 norm_grad = 0.026960 fun_val = 0.008271
# iter_number =   6 norm_grad = 0.026719 fun_val = 0.007947
# iter_number =   7 norm_grad = 0.026485 fun_val = 0.007636
# iter_number =   8 norm_grad = 0.026259 fun_val = 0.007338
# iter_number =   9 norm_grad = 0.026039 fun_val = 0.007051
# iter_number =  10 norm_grad = 0.025827 fun_val = 0.006776
# iter_number =  11 norm_grad = 0.025622 fun_val = 0.006512
# iter_number =  12 norm_grad = 0.025423 fun_val = 0.006258
# iter_number =  13 norm_grad = 0.025230 fun_val = 0.006014
# iter_number =  14 norm_grad = 0.025044 fun_val = 0.005780
# iter_number =  15 norm_grad = 0.024864 fun_val = 0.005555
# iter_number =  16 norm_grad = 0.024689 fun_val = 0.005339
# iter_number =  17 norm_grad = 0.024521 fun_val = 0.005131
# iter_number =  18 norm_grad = 0.024357 fun_val = 0.004932
# iter_number =  19 norm_grad = 0.024200 fun_val = 0.004741
# iter_number =  20 norm_grad = 0.024047 fun_val = 0.004557
# iter_number =  21 norm_grad = 0.023900 fun_val = 0.004381
# iter_number =  22 norm_grad = 0.023758 fun_val = 0.004211
# iter_number =  23 norm_grad = 0.023621 fun_val = 0.004048
# iter_number =  24 norm_grad = 0.023488 fun_val = 0.003892
# iter_number =  25 norm_grad = 0.023360 fun_val = 0.003742
# iter_number =  26 norm_grad = 0.023236 fun_val = 0.003597
# iter_number =  27 norm_grad = 0.023116 fun_val = 0.003459
# iter_number =  28 norm_grad = 0.011475 fun_val = 0.003292
# iter_number =  29 norm_grad = 0.011016 fun_val = 0.003034
# iter_number =  30 norm_grad = 0.010576 fun_val = 0.002796
# iter_number =  31 norm_grad = 0.010153 fun_val = 0.002577
# iter_number =  32 norm_grad = 0.009747 fun_val = 0.002375
# iter_number =  33 norm_grad = 0.009357 fun_val = 0.002189
# iter_number =  34 norm_grad = 0.008982 fun_val = 0.002017
# iter_number =  35 norm_grad = 0.008623 fun_val = 0.001859
# iter_number =  36 norm_grad = 0.008278 fun_val = 0.001713
# iter_number =  37 norm_grad = 0.007947 fun_val = 0.001579
# iter_number =  38 norm_grad = 0.007629 fun_val = 0.001455
# iter_number =  39 norm_grad = 0.007324 fun_val = 0.001341
# iter_number =  40 norm_grad = 0.007031 fun_val = 0.001236
# iter_number =  41 norm_grad = 0.006750 fun_val = 0.001139
# iter_number =  42 norm_grad = 0.006480 fun_val = 0.001050
# iter_number =  43 norm_grad = 0.006221 fun_val = 0.000967
# iter_number =  44 norm_grad = 0.005972 fun_val = 0.000892
# iter_number =  45 norm_grad = 0.005733 fun_val = 0.000822
# iter_number =  46 norm_grad = 0.005504 fun_val = 0.000757
# iter_number =  47 norm_grad = 0.005284 fun_val = 0.000698
# iter_number =  48 norm_grad = 0.005072 fun_val = 0.000643
# iter_number =  49 norm_grad = 0.004869 fun_val = 0.000593
# iter_number =  50 norm_grad = 0.004675 fun_val = 0.000546
# iter_number =  51 norm_grad = 0.004488 fun_val = 0.000503
# iter_number =  52 norm_grad = 0.004308 fun_val = 0.000464
# iter_number =  53 norm_grad = 0.004136 fun_val = 0.000428
# iter_number =  54 norm_grad = 0.003970 fun_val = 0.000394
# iter_number =  55 norm_grad = 0.003811 fun_val = 0.000363
# iter_number =  56 norm_grad = 0.003659 fun_val = 0.000335
# iter_number =  57 norm_grad = 0.003513 fun_val = 0.000308
# iter_number =  58 norm_grad = 0.003372 fun_val = 0.000284
# iter_number =  59 norm_grad = 0.003237 fun_val = 0.000262
# iter_number =  60 norm_grad = 0.003108 fun_val = 0.000241
# iter_number =  61 norm_grad = 0.002983 fun_val = 0.000223
# iter_number =  62 norm_grad = 0.002864 fun_val = 0.000205
# iter_number =  63 norm_grad = 0.002750 fun_val = 0.000189
# iter_number =  64 norm_grad = 0.002640 fun_val = 0.000174
# iter_number =  65 norm_grad = 0.002534 fun_val = 0.000161
# iter_number =  66 norm_grad = 0.002433 fun_val = 0.000148
# iter_number =  67 norm_grad = 0.002335 fun_val = 0.000136
# iter_number =  68 norm_grad = 0.002242 fun_val = 0.000126
# iter_number =  69 norm_grad = 0.002152 fun_val = 0.000116
# iter_number =  70 norm_grad = 0.002066 fun_val = 0.000107
# iter_number =  71 norm_grad = 0.001984 fun_val = 0.000098
# iter_number =  72 norm_grad = 0.001904 fun_val = 0.000091
# iter_number =  73 norm_grad = 0.001828 fun_val = 0.000084
# iter_number =  74 norm_grad = 0.001755 fun_val = 0.000077
# iter_number =  75 norm_grad = 0.001685 fun_val = 0.000071
# iter_number =  76 norm_grad = 0.001617 fun_val = 0.000065
# iter_number =  77 norm_grad = 0.001553 fun_val = 0.000060
# iter_number =  78 norm_grad = 0.001490 fun_val = 0.000056
# iter_number =  79 norm_grad = 0.001431 fun_val = 0.000051
# iter_number =  80 norm_grad = 0.001374 fun_val = 0.000047
# iter_number =  81 norm_grad = 0.001319 fun_val = 0.000043
# iter_number =  82 norm_grad = 0.001266 fun_val = 0.000040
# iter_number =  83 norm_grad = 0.001215 fun_val = 0.000037
# iter_number =  84 norm_grad = 0.001167 fun_val = 0.000034
# iter_number =  85 norm_grad = 0.001120 fun_val = 0.000031
# iter_number =  86 norm_grad = 0.001075 fun_val = 0.000029
# iter_number =  87 norm_grad = 0.001032 fun_val = 0.000027
# iter_number =  88 norm_grad = 0.000991 fun_val = 0.000025
# iter_number =  89 norm_grad = 0.000951 fun_val = 0.000023
# iter_number =  90 norm_grad = 0.000913 fun_val = 0.000021
# iter_number =  91 norm_grad = 0.000877 fun_val = 0.000019
# iter_number =  92 norm_grad = 0.000842 fun_val = 0.000018
# iter_number =  93 norm_grad = 0.000808 fun_val = 0.000016
# iter_number =  94 norm_grad = 0.000776 fun_val = 0.000015
# iter_number =  95 norm_grad = 0.000745 fun_val = 0.000014
# iter_number =  96 norm_grad = 0.000715 fun_val = 0.000013
# iter_number =  97 norm_grad = 0.000686 fun_val = 0.000012
# iter_number =  98 norm_grad = 0.000659 fun_val = 0.000011
# iter_number =  99 norm_grad = 0.000632 fun_val = 0.000010
# iter_number = 100 norm_grad = 0.000607 fun_val = 0.000009
# iter_number = 101 norm_grad = 0.000583 fun_val = 0.000008
# iter_number = 102 norm_grad = 0.000560 fun_val = 0.000008
# iter_number = 103 norm_grad = 0.000537 fun_val = 0.000007
# iter_number = 104 norm_grad = 0.000516 fun_val = 0.000007
# iter_number = 105 norm_grad = 0.000495 fun_val = 0.000006
# iter_number = 106 norm_grad = 0.000475 fun_val = 0.000006
# iter_number = 107 norm_grad = 0.000456 fun_val = 0.000005
# iter_number = 108 norm_grad = 0.000438 fun_val = 0.000005
# iter_number = 109 norm_grad = 0.000420 fun_val = 0.000004
# iter_number = 110 norm_grad = 0.000404 fun_val = 0.000004
# iter_number = 111 norm_grad = 0.000388 fun_val = 0.000004
# iter_number = 112 norm_grad = 0.000372 fun_val = 0.000003
# iter_number = 113 norm_grad = 0.000357 fun_val = 0.000003
# iter_number = 114 norm_grad = 0.000343 fun_val = 0.000003
# iter_number = 115 norm_grad = 0.000329 fun_val = 0.000003
# iter_number = 116 norm_grad = 0.000316 fun_val = 0.000002
# iter_number = 117 norm_grad = 0.000303 fun_val = 0.000002
# iter_number = 118 norm_grad = 0.000291 fun_val = 0.000002
# iter_number = 119 norm_grad = 0.000280 fun_val = 0.000002
# iter_number = 120 norm_grad = 0.000268 fun_val = 0.000002
# iter_number = 121 norm_grad = 0.000258 fun_val = 0.000002
# iter_number = 122 norm_grad = 0.000247 fun_val = 0.000002
# iter_number = 123 norm_grad = 0.000237 fun_val = 0.000001
# iter_number = 124 norm_grad = 0.000228 fun_val = 0.000001
# iter_number = 125 norm_grad = 0.000219 fun_val = 0.000001
# iter_number = 126 norm_grad = 0.000210 fun_val = 0.000001
# iter_number = 127 norm_grad = 0.000202 fun_val = 0.000001
# iter_number = 128 norm_grad = 0.000194 fun_val = 0.000001
# iter_number = 129 norm_grad = 0.000186 fun_val = 0.000001
# iter_number = 130 norm_grad = 0.000178 fun_val = 0.000001
# iter_number = 131 norm_grad = 0.000171 fun_val = 0.000001
# iter_number = 132 norm_grad = 0.000164 fun_val = 0.000001
# iter_number = 133 norm_grad = 0.000158 fun_val = 0.000001
# iter_number = 134 norm_grad = 0.000152 fun_val = 0.000001
# iter_number = 135 norm_grad = 0.000145 fun_val = 0.000001
# iter_number = 136 norm_grad = 0.000140 fun_val = 0.000000
# iter_number = 137 norm_grad = 0.000134 fun_val = 0.000000
# iter_number = 138 norm_grad = 0.000129 fun_val = 0.000000
# iter_number = 139 norm_grad = 0.000124 fun_val = 0.000000
# iter_number = 140 norm_grad = 0.000119 fun_val = 0.000000
# iter_number = 141 norm_grad = 0.000114 fun_val = 0.000000
# iter_number = 142 norm_grad = 0.000109 fun_val = 0.000000
# iter_number = 143 norm_grad = 0.000105 fun_val = 0.000000
# iter_number = 144 norm_grad = 0.000101 fun_val = 0.000000
# iter_number = 145 norm_grad = 0.000097 fun_val = 0.000000
# iter_number = 146 norm_grad = 0.000093 fun_val = 0.000000
# iter_number = 147 norm_grad = 0.000089 fun_val = 0.000000
# iter_number = 148 norm_grad = 0.000086 fun_val = 0.000000
# iter_number = 149 norm_grad = 0.000082 fun_val = 0.000000
# iter_number = 150 norm_grad = 0.000079 fun_val = 0.000000
# iter_number = 151 norm_grad = 0.000076 fun_val = 0.000000
# iter_number = 152 norm_grad = 0.000073 fun_val = 0.000000
# iter_number = 153 norm_grad = 0.000070 fun_val = 0.000000
# iter_number = 154 norm_grad = 0.000067 fun_val = 0.000000
# iter_number = 155 norm_grad = 0.000064 fun_val = 0.000000
# iter_number = 156 norm_grad = 0.000062 fun_val = 0.000000
# iter_number = 157 norm_grad = 0.000059 fun_val = 0.000000
# iter_number = 158 norm_grad = 0.000057 fun_val = 0.000000
# iter_number = 159 norm_grad = 0.000055 fun_val = 0.000000
# iter_number = 160 norm_grad = 0.000052 fun_val = 0.000000
# iter_number = 161 norm_grad = 0.000050 fun_val = 0.000000
# iter_number = 162 norm_grad = 0.000048 fun_val = 0.000000
# iter_number = 163 norm_grad = 0.000046 fun_val = 0.000000
# iter_number = 164 norm_grad = 0.000045 fun_val = 0.000000
# iter_number = 165 norm_grad = 0.000043 fun_val = 0.000000
# iter_number = 166 norm_grad = 0.000041 fun_val = 0.000000
# iter_number = 167 norm_grad = 0.000039 fun_val = 0.000000
# iter_number = 168 norm_grad = 0.000038 fun_val = 0.000000
# iter_number = 169 norm_grad = 0.000036 fun_val = 0.000000
# iter_number = 170 norm_grad = 0.000035 fun_val = 0.000000
# iter_number = 171 norm_grad = 0.000033 fun_val = 0.000000
# iter_number = 172 norm_grad = 0.000032 fun_val = 0.000000
# iter_number = 173 norm_grad = 0.000031 fun_val = 0.000000
# iter_number = 174 norm_grad = 0.000030 fun_val = 0.000000
# iter_number = 175 norm_grad = 0.000028 fun_val = 0.000000
# iter_number = 176 norm_grad = 0.000027 fun_val = 0.000000
# iter_number = 177 norm_grad = 0.000026 fun_val = 0.000000
# iter_number = 178 norm_grad = 0.000025 fun_val = 0.000000
# iter_number = 179 norm_grad = 0.000024 fun_val = 0.000000
# iter_number = 180 norm_grad = 0.000023 fun_val = 0.000000
# iter_number = 181 norm_grad = 0.000022 fun_val = 0.000000
# iter_number = 182 norm_grad = 0.000021 fun_val = 0.000000
# iter_number = 183 norm_grad = 0.000021 fun_val = 0.000000
# iter_number = 184 norm_grad = 0.000020 fun_val = 0.000000
# iter_number = 185 norm_grad = 0.000019 fun_val = 0.000000
# iter_number = 186 norm_grad = 0.000018 fun_val = 0.000000
# iter_number = 187 norm_grad = 0.000017 fun_val = 0.000000
# iter_number = 188 norm_grad = 0.000017 fun_val = 0.000000
# iter_number = 189 norm_grad = 0.000016 fun_val = 0.000000
# iter_number = 190 norm_grad = 0.000015 fun_val = 0.000000
# iter_number = 191 norm_grad = 0.000015 fun_val = 0.000000
# iter_number = 192 norm_grad = 0.000014 fun_val = 0.000000
# iter_number = 193 norm_grad = 0.000014 fun_val = 0.000000
# iter_number = 194 norm_grad = 0.000013 fun_val = 0.000000
# iter_number = 195 norm_grad = 0.000013 fun_val = 0.000000
# iter_number = 196 norm_grad = 0.000012 fun_val = 0.000000
# iter_number = 197 norm_grad = 0.000012 fun_val = 0.000000
# iter_number = 198 norm_grad = 0.000011 fun_val = 0.000000
# iter_number = 199 norm_grad = 0.000011 fun_val = 0.000000
# iter_number = 200 norm_grad = 0.000010 fun_val = 0.000000
# iter_number = 201 norm_grad = 0.000010 fun_val = 0.000000
